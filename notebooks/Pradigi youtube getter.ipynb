# %%
import youtube_helper

def test_get_youtube_info():

    tree = youtube_helper.get_youtube_info('https://www.youtube.com/playlist?list=PLHSER0n5wjJybb22EtsajzufpozEo5vLE')
    assert tree['title']
    assert len(tree['children']) == 22

# %%
data = youtube_helper.get_youtube_info('https://www.youtube.com/playlist?list=PLHSER0n5wjJybb22EtsajzufpozEo5vLE')
# Out:
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2018.05.01
# [debug] Git HEAD: 636eae0
# [debug] Python version 3.6.5 (CPython) - Darwin-17.5.0-x86_64-i386-64bit
# [debug] exe versions: ffmpeg 3.4.1, ffprobe 3.4.1, phantomjs 2.1.1
# [debug] Proxy map: {}
# [youtube:playlist] PLHSER0n5wjJybb22EtsajzufpozEo5vLE: Downloading webpage
# [download] Downloading playlist: Automobile
# [youtube:playlist] playlist Automobile: Downloading 22 videos
# [download] Downloading video 1 of 22
# [youtube] 4DrLWGFXvwc: Downloading webpage
# [youtube] 4DrLWGFXvwc: Downloading video info webpage
# [youtube] 4DrLWGFXvwc: Extracting video information
# [youtube] 4DrLWGFXvwc: Downloading MPD manifest
# [youtube] 4DrLWGFXvwc: Downloading MPD manifest
# [debug] Default format spec: bestvideo+bestaudio/best
# [download] Downloading video 2 of 22
# [youtube] toLkkUOW7ug: Downloading webpage
# [youtube] toLkkUOW7ug: Downloading video info webpage
# ...

# %%
data
# Out:
# {'id': 'PLHSER0n5wjJybb22EtsajzufpozEo5vLE',
#  'title': 'Automobile',
#  'description': '',
#  'thumbnail': '',
#  'source_url': 'https://www.youtube.com/playlist?list=PLHSER0n5wjJybb22EtsajzufpozEo5vLE',
#  'tags': [],
#  'subtitles': {},
#  'requested_subtitles': '',
#  'artist': '',
#  'license': '',
#  'kind': 'playlist',
#  'children': [{'id': '4DrLWGFXvwc',
#    'title': 'इंजिन ऑइल बदलना',
#    'description': '',
#    'thumbnail': 'https://i.ytimg.com/vi/4DrLWGFXvwc/maxresdefault.jpg',
#    'source_url': 'https://www.youtube.com/watch?v=4DrLWGFXvwc',
#    'tags': [],
#    'subtitles': {},
#    'requested_subtitles': None,
#    'artist': '',
#    'license': 'Standard YouTube License',
#    'kind': 'video'},
#   {'id': 'toLkkUOW7ug',
#    'title': 'डिफ्रंशियल ऑइल बदलना',
#    'description': '',
#    'thumbnail': 'https://i.ytimg.com/vi/toLkkUOW7ug/maxresdefault.jpg',
#    'source_url': 'https://www.youtube.com/watch?v=toLkkUOW7ug',
#    'tags': [],
#    'subtitles': {},
# ...

# %%
from chef import get_youtube_playlist_subtree

# %%
subtree = get_youtube_playlist_subtree('https://www.youtube.com/playlist?list=PLHSER0n5wjJybb22EtsajzufpozEo5vLE')
# Out:
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2018.05.01
# [debug] Git HEAD: b45b4f4
# [debug] Python version 3.6.5 (CPython) - Darwin-17.5.0-x86_64-i386-64bit
# [debug] exe versions: ffmpeg 3.4.1, ffprobe 3.4.1, phantomjs 2.1.1
# [debug] Proxy map: {}
# [youtube:playlist] PLHSER0n5wjJybb22EtsajzufpozEo5vLE: Downloading webpage
# [download] Downloading playlist: Automobile
# [youtube:playlist] playlist Automobile: Downloading 22 videos
# [download] Downloading video 1 of 22
# [youtube] 4DrLWGFXvwc: Downloading webpage
# [youtube] 4DrLWGFXvwc: Downloading video info webpage
# [youtube] 4DrLWGFXvwc: Extracting video information
# [youtube] 4DrLWGFXvwc: Downloading MPD manifest
# [youtube] 4DrLWGFXvwc: Downloading MPD manifest
# [debug] Default format spec: bestvideo+bestaudio/best
# [download] Downloading video 2 of 22
# [youtube] toLkkUOW7ug: Downloading webpage
# [youtube] toLkkUOW7ug: Downloading video info webpage
# ...

# %%
subtree
# Out:
# {'kind': 'youtube_playlist',
#  'source_id': 'PLHSER0n5wjJybb22EtsajzufpozEo5vLE',
#  'title': 'Automobile',
#  'description': 'source_url=https://www.youtube.com/playlist?list=PLHSER0n5wjJybb22EtsajzufpozEo5vLE',
#  'children': [{'kind': 'YouTubeVideoResource',
#    'source_id': '4DrLWGFXvwc',
#    'title': 'इंजिन ऑइल बदलना',
#    'description': 'source_url=https://www.youtube.com/watch?v=4DrLWGFXvwc',
#    'thumbnail_url': 'https://i.ytimg.com/vi/4DrLWGFXvwc/maxresdefault.jpg',
#    'youtube_id': '4DrLWGFXvwc'},
#   {'kind': 'YouTubeVideoResource',
#    'source_id': 'toLkkUOW7ug',
#    'title': 'डिफ्रंशियल ऑइल बदलना',
#    'description': 'source_url=https://www.youtube.com/watch?v=toLkkUOW7ug',
#    'thumbnail_url': 'https://i.ytimg.com/vi/toLkkUOW7ug/maxresdefault.jpg',
#    'youtube_id': 'toLkkUOW7ug'},
#   {'kind': 'YouTubeVideoResource',
#    'source_id': 'fyKEj9qFxH0',
#    'title': 'कार के पुर्जे - बोनेट',
# ...
