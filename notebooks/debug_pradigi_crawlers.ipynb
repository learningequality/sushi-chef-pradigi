# %% [markdown]
# # Crawling the website
#
# First step is to crawl the website https://prathamopenschool.org/

# %%
# the crawler class
from pradigi_crawlers import PraDigiCrawler

# %%
# Let's use the Kannada as the sample:
crawler = PraDigiCrawler(lang='hi')
web_resource_tree = crawler.crawl()
# Out:
# Downloaded page https://www.prathamopenschool.org/hn/ title:POS
# in on_lang_page https://www.prathamopenschool.org/hn/
# found topic: Mathematics: गणित
# found topic: English: अंग्रेजी
# found topic: Science: विज्ञान
# found topic: Hospitality: आदरातिथ्य
# found topic: Automobile: ऑटोमोटिव्ह
# found topic: Electric: इलेक्ट्रिकल
# found topic: Construction: भवन-निर्माण
# found topic: Healthcare: स्वास्थ्य सेवा
# found topic: Beauty: ब्युटी
# found topic: Financial Literacy: Financial Literacy
# found topic: Health: स्वास्थ्य
# found top-level CRS page: CRS136: खेलकूद
# found topic: Sangeet: संगीत
# found top-level CRS page: CRS217: नाटक
# found topic: Art Project: आर्ट प्रोजेक्ट
# found fun page: Fun: मौज
# found story page: Story: कहानियाँ
# found topic: KhelBadi: खेल-बाड़ी
# FOUND three-tab special_subtopic_page page: CRS123: खेल-पुरी
# Downloaded page https://www.prathamopenschool.org/hn/Course/Mathematics title:Course
# ...

# %%
# !ls -lh chefdata/trees/pradigi_kn_web_resource_tree.json
# Out:
# -rw-r--r-- 1 dj dj 234K Nov  9 12:11 chefdata/trees/pradigi_kn_web_resource_tree.json

# %%
# open the file chefdata/trees/pradigi_kn_web_resource_tree.json to see the result

# %% [markdown]
# The same process is repeated for the other languages, writing the output in `chefdata/trees/pradigi_{lang}_web_resource_tree.json`
