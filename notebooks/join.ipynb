# %%
from chef import find_games_for_lang, TEST_GAMENAMES, download_structure_csv

# %%
# for lang in ['hi', 'en']:
#     for name in TEST_GAMENAMES:
#         game = find_game_for_lang(name, lang)
#         if game is None:
#             print('Game', name, 'not available in', lang)

# %%
import json
from chef import flatten_tree

data = json.load(open('chefdata/trees/pradigi_games_all_langs.json','r'))

# %%
gamelist = flatten_tree(data)
for game in gamelist:
    if len(game['title']) == 0:
        print('The game in', game['language_en'], 'appears without a title, but zip is there:', game['url'])

# %%
from chef import write_games_by_language_csv

write_games_by_language_csv()

# %%
import json
from chef import flatten_tree

data = json.load(open('chefdata/trees/pradigi_games_all_langs.json','r'))
gamelist = flatten_tree(data)

uniq_langs = set()
for game in gamelist:
    uniq_langs.add(game['language_en'])

# %%
uniq_langs.difference(['Assamese'])
# Out:
# {'Bangali',
#  'English',
#  'Gujarati',
#  'Hindi',
#  'Kannada',
#  'Marathi',
#  'Odiya',
#  'Punjabi',
#  'Tamil',
#  'Telugu'}

# %%
import json
from chef import getlang_by_language_en

lookup = {}
for lang_name in uniq_langs:
    lang_obj = getlang_by_language_en(lang_name)
    lookup[lang_obj.code] = {'language_en': lang_name, 'gamesrepo_suffixes':[], 'strings':{}}
print(json.dumps(lookup, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b4da4d9e867> in <module>()
#       3
#       4 lookup = {}
# ----> 5 for lang_name in uniq_langs:
#       6     lang_obj = getlang_by_language_en(lang_name)
#       7     lookup[lang_obj.code] = {'language_en': lang_name, 'gamesrepo_suffixes':[], 'strings':{}}
#
# NameError: name 'uniq_langs' is not defined

# %%
lookup.keys()
# Out:
# dict_keys(['or', 'bn', 'pnb', 'kn', 'ta', 'te', 'mr', 'hi', 'gu', 'en', 'as'])

# %%
from chef import find_undocumented_games
find_undocumented_games()
# Out:
# AbKahanHai_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/AbKahanHai_KKS_Hindi.zip
# AksharMatra_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/AksharMatra_HI_Hindi.zip
# AksharMatra_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/AksharMatra_MR_Marathi.zip
# AwazChitraAS_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/AwazChitraAS_Assamese.zip
# BalloonGame_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BalloonGame_KKS_Hindi.zip
# Barahghar_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Barahghar_KKS_Gujarati.zip
# BarakhadiBanao_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BarakhadiBanao_KKS_Hindi.zip
# BarakhadiSeekho_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BarakhadiSeekho_KKS_Hindi.zip
# BhalooKiBarakhadi_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BhalooKiBarakhadi_KKS_Hindi.zip
# Bhaloo_ki_Barakhadi_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Bhaloo_ki_Barakhadi_KKS_Gujarati.zip
# BolBacchaBol_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BolBacchaBol_HI_Hindi.zip
# BolBacchaBol_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/BolBacchaBol_MR_Marathi.zip
# ChitraVichitra_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/ChitraVichitra_HI_Hindi.zip
# ChitraVichitra_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/ChitraVichitra_MR_Marathi.zip
# CorrectPair	English	http://www.gamerepo.prathamcms.org/Zip/English/CorrectPair_English.zip
# Cricket_AS	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/Cricket_AS_Assamese.zip
# Cricket_BN	Bangali	http://www.gamerepo.prathamcms.org/Zip/Bangali/Cricket_BN_Bangali.zip
# Cricket_GJ	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Cricket_GJ_Gujarati.zip
# Cricket_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Cricket_HI_Hindi.zip
# Cricket_KN	Kannada	http://www.gamerepo.prathamcms.org/Zip/Kannada/Cricket_KN_Kannada.zip
# Cricket_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/Cricket_MR_Marathi.zip
# Cricket_OD	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/Cricket_OD_Odiya.zip
# Cricket_PN	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/Cricket_PN_Punjabi.zip
# Cricket_TL	Telugu	http://www.gamerepo.prathamcms.org/Zip/Telugu/Cricket_TL_Telugu.zip
# Cricket_TM	Tamil	http://www.gamerepo.prathamcms.org/Zip/Tamil/Cricket_TM_Tamil.zip
# DingDangDing_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/DingDangDing_HI_Hindi.zip
# DingDangDing_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/DingDangDing_MR_Marathi.zip
# EkSeAnek_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/EkSeAnek_KKS_Gujarati.zip
# Golmaal_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Golmaal_HI_Hindi.zip
# Golmaal_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/Golmaal_MR_Marathi.zip
# Gubbare_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Gubbare_KKS_Gujarati.zip
# HelloHello_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/HelloHello_KKS_Gujarati.zip
# Jigsaw	English	http://www.gamerepo.prathamcms.org/Zip/English/Jigsaw_English.zip
# Judwa_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Judwa_KKS_Gujarati.zip
# JumbleTumble	English	http://www.gamerepo.prathamcms.org/Zip/English/JumbleTumble_English.zip
# JumbleTumble_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/JumbleTumble_HI_Hindi.zip
# MindMapWheel_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/MindMapWheel_KKS_Hindi.zip
# MujheDhundho_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/MujheDhundho_KKS_Gujarati.zip
# Nadiya Ke Paar	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Nadiya Ke Paar_Hindi.zip
# NumberRecognition	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/NumberRecognition_Hindi.zip
# NumberRecognition2	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/NumberRecognition2_Hindi.zip
# PattaPalat_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/PattaPalat_KKS_Hindi.zip
# PointMeOut	English	http://www.gamerepo.prathamcms.org/Zip/English/PointMeOut_English.zip
# RailGadi_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/RailGadi_HI_Hindi.zip
# RailGadi_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/RailGadi_MR_Marathi.zip
# Suno_Pehchano_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Suno_Pehchano_KKS_Gujarati.zip
# TracingGame_AS	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/TracingGame_AS_Assamese.zip
# TracingGame_BN	Bangali	http://www.gamerepo.prathamcms.org/Zip/Bangali/TracingGame_BN_Bangali.zip
# TracingGame_GJ	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/TracingGame_GJ_Gujarati.zip
# TracingGame_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/TracingGame_HI_Hindi.zip
# TracingGame_KN	Kannada	http://www.gamerepo.prathamcms.org/Zip/Kannada/TracingGame_KN_Kannada.zip
# TracingGame_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/TracingGame_MR_Marathi.zip
# TracingGame_OD	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/TracingGame_OD_Odiya.zip
# TracingGame_PN	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/TracingGame_PN_Punjabi.zip
# TracingGame_TL	Telugu	http://www.gamerepo.prathamcms.org/Zip/Telugu/TracingGame_TL_Telugu.zip
# TracingGame_TM	Tamil	http://www.gamerepo.prathamcms.org/Zip/Tamil/TracingGame_TM_Tamil.zip
# UlatPalat2Science	English	http://www.gamerepo.prathamcms.org/Zip/English/UlatPalat2Science_English.zip
# UlatPalatScience	English	http://www.gamerepo.prathamcms.org/Zip/English/UlatPalatScience_English.zip
# YouSaid	English	http://www.gamerepo.prathamcms.org/Zip/English/YouSaid_English.zip
# fonts_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/fonts_Assamese.zip
# fonts_Odiya	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/fonts_Odiya.zip
# fonts_Punjabi	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/fonts_Punjabi.zip
# js_Marathi	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/js_Marathi.zip
# AbKahanHai
# AksharMatra
# AwazChitraAS
# BalloonGame
# Barahghar
# BarakhadiBanao
# BarakhadiSeekho
# BhalooKiBarakhadi
# Bhaloo_ki_Barakhadi
# BolBacchaBol
# ChitraVichitra
# CorrectPair
# Cricket
# DingDangDing
# EkSeAnek
# Golmaal
# Gubbare
# HelloHello
# Jigsaw
# Judwa
# JumbleTumble
# MindMapWheel
# MujheDhundho
# Nadiya Ke Paar
# NumberRecognition
# NumberRecognition2
# PattaPalat
# PointMeOut
# RailGadi
# Suno_Pehchano
# TracingGame
# UlatPalat2Science
# UlatPalatScience
# YouSaid
# fonts
# js

# %%
00
s = "Aksharkhadi_KKS"
s.replace('_KKS', '')
# Out:
# 'Aksharkhadi'

# %%
from chef import load_pradigi_structure, get_all_game_names
games_info = load_pradigi_structure()

# %%
games_info
# Out:
# [{'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Color',
#   'Name on gamerepo (before lang underscore)': 'Color',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Colour / Rang',
#   'Name on gamerepo (before lang underscore)': 'Coloring',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Golmaal',
#   'Name on gamerepo (before lang underscore)': 'Golmaal',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Rhythm',
#   'Name on gamerepo (before lang underscore)': 'Rhythm',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Sangeet',
#   'Name on gamerepo (before lang underscore)': 'Sangeet',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'TracingGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Akshar Khadi',
#   'Name on gamerepo (before lang underscore)': 'Aksharkhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Awaz chitra',
#   'Name on gamerepo (before lang underscore)': 'AwazChitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Awaz pehchano',
#   'Name on gamerepo (before lang underscore)': 'AwazPehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Bol Baccha Bol',
#   'Name on gamerepo (before lang underscore)': 'BolBacchaBol',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Guess Me',
#   'Name on gamerepo (before lang underscore)': 'GuessMe',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Pehchano',
#   'Name on gamerepo (before lang underscore)': 'MujhePehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Chitra Vichitra',
#   'Name on gamerepo (before lang underscore)': 'ChitraVichitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Curious cases',
#   'Name on gamerepo (before lang underscore)': 'CuriousCases?',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Ding Dang Ding',
#   'Name on gamerepo (before lang underscore)': 'DingDangDing',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Number kas',
#   'Name on gamerepo (before lang underscore)': 'NumberKas',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Rail Gadi',
#   'Name on gamerepo (before lang underscore)': 'RailGadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'RailGadi ',
#   'Name on gamerepo (before lang underscore)': 'RailGadi ',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Point me out',
#   'Name on gamerepo (before lang underscore)': 'PointMeOut',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Awaz pehchano',
#   'Name on gamerepo (before lang underscore)': 'AwazPehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Color',
#   'Name on gamerepo (before lang underscore)': 'Color',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Colour / Rang',
#   'Name on gamerepo (before lang underscore)': 'Coloring',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Jigsaw (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'Jigsaw',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Pehchano',
#   'Name on gamerepo (before lang underscore)': 'MujhePehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': '(double check name)',
#   'Name': 'Nadiya Ke Paar',
#   'Name on gamerepo (before lang underscore)': 'Nadiya Ke Paar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Rhythm',
#   'Name on gamerepo (before lang underscore)': 'Rhythm',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Sangeet',
#   'Name on gamerepo (before lang underscore)': 'Sangeet',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ab Kahan Hai',
#   'Name on gamerepo (before lang underscore)': 'AbKahanHai',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Age Piche',
#   'Name on gamerepo (before lang underscore)': 'AgePiche',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Akshar Khadi',
#   'Name on gamerepo (before lang underscore)': 'Aksharkhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Akshar Matra Shabd Yatra',
#   'Name on gamerepo (before lang underscore)': 'AksharMatra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Balloon Game',
#   'Name on gamerepo (before lang underscore)': 'BalloonGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barahghar',
#   'Name on gamerepo (before lang underscore)': 'Barahghar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi Banao',
#   'Name on gamerepo (before lang underscore)': 'BarakhadiBanao',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi Seekho',
#   'Name on gamerepo (before lang underscore)': 'BarakhadiSeekho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Bhaloo ki Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Bhaloo_ki_Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Bhaloo ki Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'BhalooKiBarakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ek se Anek',
#   'Name on gamerepo (before lang underscore)': 'EkSeAnek',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'GaltiMaaf Sudharo',
#   'Name on gamerepo (before lang underscore)': 'GaltiMaafSudharo',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Gubbare',
#   'Name on gamerepo (before lang underscore)': 'Gubbare',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Hello Hello',
#   'Name on gamerepo (before lang underscore)': 'HelloHello',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Judwa',
#   'Name on gamerepo (before lang underscore)': 'Judwa',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Kahaniya',
#   'Name on gamerepo (before lang underscore)': 'Kahaniyaan',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mind Map Wheel',
#   'Name on gamerepo (before lang underscore)': 'MindMapWheel',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Dhundho',
#   'Name on gamerepo (before lang underscore)': 'MujheDhundho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Patta Palat',
#   'Name on gamerepo (before lang underscore)': 'PattaPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Shabda Chitra',
#   'Name on gamerepo (before lang underscore)': 'ShabdhChitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Suno Pehchano',
#   'Name on gamerepo (before lang underscore)': 'Suno_Pehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Thik Thak',
#   'Name on gamerepo (before lang underscore)': 'ThikThak',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'TracingGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ulat palat',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Dhoom 1',
#   'Name on gamerepo (before lang underscore)': 'Dhoom_1',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Jano Number',
#   'Name on gamerepo (before lang underscore)': 'JaanoNumber',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'LineLagao',
#   'Name on gamerepo (before lang underscore)': 'LineLagao',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number 123',
#   'Name on gamerepo (before lang underscore)': 'Number123',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number kas',
#   'Name on gamerepo (before lang underscore)': 'NumberKas',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number Recognition',
#   'Name on gamerepo (before lang underscore)': 'NumberRecognition',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number Recognition',
#   'Name on gamerepo (before lang underscore)': 'NumberRecognition2',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'For Marathi take version from the English repo',
#   'Name': 'Jumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'JumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': '(double check name)',
#   'Name': 'Atulya Bharat',
#   'Name on gamerepo (before lang underscore)': 'Atulya Bharat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jigsaw (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'Jigsaw',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Palat',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Akshar Matra Shabd Yatra',
#   'Name on gamerepo (before lang underscore)': 'AksharMatra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Correct Pair',
#   'Name on gamerepo (before lang underscore)': 'CorrectPair',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jano Number',
#   'Name on gamerepo (before lang underscore)': 'JaanoNumber',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'JumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Point me out',
#   'Name on gamerepo (before lang underscore)': 'PointMeOut',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Count & know',
#   'Name on gamerepo (before lang underscore)': 'CountAndKnow',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Count it',
#   'Name on gamerepo (before lang underscore)': 'CountIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'De Dana Dan',
#   'Name on gamerepo (before lang underscore)': 'Cricket',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'No game with similar name found in gamesrepo',
#   'Name': 'De dana dan',
#   'Name on gamerepo (before lang underscore)': 'De dana dan',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Dhoom 2',
#   'Name on gamerepo (before lang underscore)': 'Dhoom_2',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Ulat Palat (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat2Science',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Science'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Ulat Palat (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'UlatPalatScience',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Science'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Science'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Automotive'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Beauty'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Construction'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Electrical'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'English- Hindi',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Healthcare'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Hospitality'}]

# %%
game_names = get_all_game_names()

# %%
game_names
# Out:
# ['ABCD',
#  'fixUpMixUp',
#  'Aakar',
#  'Color',
#  'Coloring',
#  'Golmaal',
#  'Rhythm',
#  'Sangeet',
#  'TracingGame',
#  'Aksharkhadi',
#  'AwazChitra',
#  'AwazPehchano',
#  'Barakhadi',
#  'BolBacchaBol',
#  'GuessMe',
#  'MujhePehchano',
#  'ChitraVichitra',
#  'CuriousCases?',
#  'DingDangDing',
#  'NumberKas',
#  'RailGadi',
#  'CrumbleTumble',
#  'FlipIt',
#  'GuessWho',
#  'LetterBox',
#  'PointMeOut',
#  'YouSaid',
#  'Jigsaw',
#  'Nadiya Ke Paar',
#  'GuessMe?',
#  'AbKahanHai',
#  'AgePiche',
#  'AksharMatra',
#  'BalloonGame',
#  'Barahghar',
#  'BarakhadiBanao',
#  'BarakhadiSeekho',
#  'Bhaloo_ki_Barakhadi',
#  'BhalooKiBarakhadi',
#  'EkSeAnek',
#  'GaltiMaafSudharo',
#  'Gubbare',
#  'HelloHello',
#  'Judwa',
#  'Kahaniyaan',
#  'MindMapWheel',
#  'MujheDhundho',
#  'PattaPalat',
#  'ShabdhChitra',
#  'Suno_Pehchano',
#  'ThikThak',
#  'UlatPalat',
#  'Dhoom_1',
#  'JaanoNumber',
#  'LineLagao',
#  'Number123',
#  'NumberRecognition',
#  'NumberRecognition2',
#  'JumbleTumble',
#  'Atulya Bharat',
#  'CorrectPair',
#  'CountAndKnow',
#  'CountIt',
#  'Cricket',
#  'De dana dan',
#  'Dhoom_2',
#  'UlatPalat2Science',
#  'UlatPalatScience']

# %%
from chef import find_undocumented_games

# %%
find_undocumented_games()
# Out:
# fonts_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/fonts_Assamese.zip
# fonts_Odiya	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/fonts_Odiya.zip
# fonts_Punjabi	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/fonts_Punjabi.zip
# js_Marathi	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/js_Marathi.zip
# fonts
# js

# %%
filter_fn = lambda node: True

# %%
filter_fn('33')
# Out:
# True

# %%
from chef import TEMPLATE_FOR_LANG

# %%
tree_template = TEMPLATE_FOR_LANG.copy()

# %%
tree_template
# Out:
# {'children': [{'children': [{'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Story'},
#     {'children': [], 'title': 'Games'}],
#    'title': '3-6 years'},
#   {'children': [{'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Story'},
#     {'children': [], 'title': 'Games'}],
#    'title': '6-10 years'},
#   {'children': [{'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Health'},
#     {'children': [], 'title': 'Science'},
#     {'children': [], 'title': 'Std8'},
#     {'children': [], 'title': 'Fun'},
#     {'children': [], 'title': 'Games'}],
#    'title': '8-14 years'},
#   {'children': [{'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Beauty'},
#     {'children': [], 'title': 'Automotive'},
#     {'children': [], 'title': 'Healthcare'},
#     {'children': [], 'title': 'Construction'},
#     {'children': [], 'title': 'Hospitality'},
#     {'children': [], 'title': 'Electrical'},
#     {'children': [], 'title': 'Games'}],
#    'title': '14 and above'}],
#  'kind': 'lang_template'}

# %%
from chef import find_games_for_lang
games = find_games_for_lang('Aakar', 'hi')

# %%
games
# Out:
# [{'children': [],
#   'kind': 'PradigiGameZipResource',
#   'language_en': 'Hindi',
#   'last_modified': '2/8/18 12:30 PM',
#   'main_file': 'http://www.gamerepo.prathamcms.org/Game/Hindi/Aakar_KKS/index.html',
#   'title': 'Aakar_KKS',
#   'url': 'http://www.gamerepo.prathamcms.org/Zip/Hindi/Aakar_KKS_Hindi.zip'}]
