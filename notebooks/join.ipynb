# %%
from chef import find_games_for_lang, TEST_GAMENAMES, download_structure_csv

# %%
# for lang in ['hi', 'en']:
#     for name in TEST_GAMENAMES:
#         game = find_game_for_lang(name, lang)
#         if game is None:
#             print('Game', name, 'not available in', lang)

# %%
import json
from chef import flatten_tree

data = json.load(open('chefdata/trees/pradigi_games_all_langs.json','r'))

# %%
gamelist = flatten_tree(data)
for game in gamelist:
    if len(game['title']) == 0:
        print('The game in', game['language_en'], 'appears without a title, but zip is there:', game['url'])

# %%
from chef import write_games_by_language_csv

write_games_by_language_csv()

# %%
import json
from chef import flatten_tree

data = json.load(open('chefdata/trees/pradigi_games_all_langs.json','r'))
gamelist = flatten_tree(data)

uniq_langs = set()
for game in gamelist:
    uniq_langs.add(game['language_en'])

# %%
uniq_langs.difference(['Assamese'])
# Out:
# {'Bangali',
#  'English',
#  'Gujarati',
#  'Hindi',
#  'Kannada',
#  'Marathi',
#  'Odiya',
#  'Punjabi',
#  'Tamil',
#  'Telugu'}

# %%
import json
from chef import getlang_by_language_en

lookup = {}
for lang_name in uniq_langs:
    lang_obj = getlang_by_language_en(lang_name)
    lookup[lang_obj.code] = {'language_en': lang_name, 'gamesrepo_suffixes':[], 'strings':{}}
print(json.dumps(lookup, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b4da4d9e867> in <module>()
#       3
#       4 lookup = {}
# ----> 5 for lang_name in uniq_langs:
#       6     lang_obj = getlang_by_language_en(lang_name)
#       7     lookup[lang_obj.code] = {'language_en': lang_name, 'gamesrepo_suffixes':[], 'strings':{}}
#
# NameError: name 'uniq_langs' is not defined

# %%
lookup.keys()
# Out:
# dict_keys(['or', 'bn', 'pnb', 'kn', 'ta', 'te', 'mr', 'hi', 'gu', 'en', 'as'])

# %%
from chef import find_undocumented_games
find_undocumented_games()
# Out:
# AbKahanHai_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/AbKahanHai_KKS_Hindi.zip
# AksharMatra_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/AksharMatra_HI_Hindi.zip
# AksharMatra_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/AksharMatra_MR_Marathi.zip
# AwazChitraAS_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/AwazChitraAS_Assamese.zip
# BalloonGame_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BalloonGame_KKS_Hindi.zip
# Barahghar_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Barahghar_KKS_Gujarati.zip
# BarakhadiBanao_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BarakhadiBanao_KKS_Hindi.zip
# BarakhadiSeekho_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BarakhadiSeekho_KKS_Hindi.zip
# BhalooKiBarakhadi_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BhalooKiBarakhadi_KKS_Hindi.zip
# Bhaloo_ki_Barakhadi_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Bhaloo_ki_Barakhadi_KKS_Gujarati.zip
# BolBacchaBol_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/BolBacchaBol_HI_Hindi.zip
# BolBacchaBol_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/BolBacchaBol_MR_Marathi.zip
# ChitraVichitra_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/ChitraVichitra_HI_Hindi.zip
# ChitraVichitra_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/ChitraVichitra_MR_Marathi.zip
# CorrectPair	English	http://www.gamerepo.prathamcms.org/Zip/English/CorrectPair_English.zip
# Cricket_AS	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/Cricket_AS_Assamese.zip
# Cricket_BN	Bangali	http://www.gamerepo.prathamcms.org/Zip/Bangali/Cricket_BN_Bangali.zip
# Cricket_GJ	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Cricket_GJ_Gujarati.zip
# Cricket_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Cricket_HI_Hindi.zip
# Cricket_KN	Kannada	http://www.gamerepo.prathamcms.org/Zip/Kannada/Cricket_KN_Kannada.zip
# Cricket_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/Cricket_MR_Marathi.zip
# Cricket_OD	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/Cricket_OD_Odiya.zip
# Cricket_PN	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/Cricket_PN_Punjabi.zip
# Cricket_TL	Telugu	http://www.gamerepo.prathamcms.org/Zip/Telugu/Cricket_TL_Telugu.zip
# Cricket_TM	Tamil	http://www.gamerepo.prathamcms.org/Zip/Tamil/Cricket_TM_Tamil.zip
# DingDangDing_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/DingDangDing_HI_Hindi.zip
# DingDangDing_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/DingDangDing_MR_Marathi.zip
# EkSeAnek_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/EkSeAnek_KKS_Gujarati.zip
# Golmaal_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Golmaal_HI_Hindi.zip
# Golmaal_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/Golmaal_MR_Marathi.zip
# Gubbare_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Gubbare_KKS_Gujarati.zip
# HelloHello_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/HelloHello_KKS_Gujarati.zip
# Jigsaw	English	http://www.gamerepo.prathamcms.org/Zip/English/Jigsaw_English.zip
# Judwa_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Judwa_KKS_Gujarati.zip
# JumbleTumble	English	http://www.gamerepo.prathamcms.org/Zip/English/JumbleTumble_English.zip
# JumbleTumble_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/JumbleTumble_HI_Hindi.zip
# MindMapWheel_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/MindMapWheel_KKS_Hindi.zip
# MujheDhundho_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/MujheDhundho_KKS_Gujarati.zip
# Nadiya Ke Paar	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/Nadiya Ke Paar_Hindi.zip
# NumberRecognition	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/NumberRecognition_Hindi.zip
# NumberRecognition2	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/NumberRecognition2_Hindi.zip
# PattaPalat_KKS	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/PattaPalat_KKS_Hindi.zip
# PointMeOut	English	http://www.gamerepo.prathamcms.org/Zip/English/PointMeOut_English.zip
# RailGadi_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/RailGadi_HI_Hindi.zip
# RailGadi_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/RailGadi_MR_Marathi.zip
# Suno_Pehchano_KKS	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/Suno_Pehchano_KKS_Gujarati.zip
# TracingGame_AS	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/TracingGame_AS_Assamese.zip
# TracingGame_BN	Bangali	http://www.gamerepo.prathamcms.org/Zip/Bangali/TracingGame_BN_Bangali.zip
# TracingGame_GJ	Gujarati	http://www.gamerepo.prathamcms.org/Zip/Gujarati/TracingGame_GJ_Gujarati.zip
# TracingGame_HI	Hindi	http://www.gamerepo.prathamcms.org/Zip/Hindi/TracingGame_HI_Hindi.zip
# TracingGame_KN	Kannada	http://www.gamerepo.prathamcms.org/Zip/Kannada/TracingGame_KN_Kannada.zip
# TracingGame_MR	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/TracingGame_MR_Marathi.zip
# TracingGame_OD	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/TracingGame_OD_Odiya.zip
# TracingGame_PN	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/TracingGame_PN_Punjabi.zip
# TracingGame_TL	Telugu	http://www.gamerepo.prathamcms.org/Zip/Telugu/TracingGame_TL_Telugu.zip
# TracingGame_TM	Tamil	http://www.gamerepo.prathamcms.org/Zip/Tamil/TracingGame_TM_Tamil.zip
# UlatPalat2Science	English	http://www.gamerepo.prathamcms.org/Zip/English/UlatPalat2Science_English.zip
# UlatPalatScience	English	http://www.gamerepo.prathamcms.org/Zip/English/UlatPalatScience_English.zip
# YouSaid	English	http://www.gamerepo.prathamcms.org/Zip/English/YouSaid_English.zip
# fonts_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/fonts_Assamese.zip
# fonts_Odiya	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/fonts_Odiya.zip
# fonts_Punjabi	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/fonts_Punjabi.zip
# js_Marathi	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/js_Marathi.zip
# AbKahanHai
# AksharMatra
# AwazChitraAS
# BalloonGame
# Barahghar
# BarakhadiBanao
# BarakhadiSeekho
# BhalooKiBarakhadi
# Bhaloo_ki_Barakhadi
# BolBacchaBol
# ChitraVichitra
# CorrectPair
# Cricket
# DingDangDing
# EkSeAnek
# Golmaal
# Gubbare
# HelloHello
# Jigsaw
# Judwa
# JumbleTumble
# MindMapWheel
# MujheDhundho
# Nadiya Ke Paar
# NumberRecognition
# NumberRecognition2
# PattaPalat
# PointMeOut
# RailGadi
# Suno_Pehchano
# TracingGame
# UlatPalat2Science
# UlatPalatScience
# YouSaid
# fonts
# js

# %%
00
s = "Aksharkhadi_KKS"
s.replace('_KKS', '')
# Out:
# 'Aksharkhadi'

# %%
from chef import load_pradigi_structure, get_all_game_names
games_info = load_pradigi_structure()

# %%
games_info
# Out:
# [{'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Color',
#   'Name on gamerepo (before lang underscore)': 'Color',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Colour / Rang',
#   'Name on gamerepo (before lang underscore)': 'Coloring',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Golmaal',
#   'Name on gamerepo (before lang underscore)': 'Golmaal',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Rhythm',
#   'Name on gamerepo (before lang underscore)': 'Rhythm',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Sangeet',
#   'Name on gamerepo (before lang underscore)': 'Sangeet',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'TracingGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Akshar Khadi',
#   'Name on gamerepo (before lang underscore)': 'Aksharkhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Awaz chitra',
#   'Name on gamerepo (before lang underscore)': 'AwazChitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Awaz pehchano',
#   'Name on gamerepo (before lang underscore)': 'AwazPehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Bol Baccha Bol',
#   'Name on gamerepo (before lang underscore)': 'BolBacchaBol',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Guess Me',
#   'Name on gamerepo (before lang underscore)': 'GuessMe',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Pehchano',
#   'Name on gamerepo (before lang underscore)': 'MujhePehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Chitra Vichitra',
#   'Name on gamerepo (before lang underscore)': 'ChitraVichitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Curious cases',
#   'Name on gamerepo (before lang underscore)': 'CuriousCases?',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Ding Dang Ding',
#   'Name on gamerepo (before lang underscore)': 'DingDangDing',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Number kas',
#   'Name on gamerepo (before lang underscore)': 'NumberKas',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'Rail Gadi',
#   'Name on gamerepo (before lang underscore)': 'RailGadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '3-6 years',
#   'LE Comments': None,
#   'Name': 'RailGadi ',
#   'Name on gamerepo (before lang underscore)': 'RailGadi ',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Point me out',
#   'Name on gamerepo (before lang underscore)': 'PointMeOut',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Awaz pehchano',
#   'Name on gamerepo (before lang underscore)': 'AwazPehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Color',
#   'Name on gamerepo (before lang underscore)': 'Color',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Colour / Rang',
#   'Name on gamerepo (before lang underscore)': 'Coloring',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Jigsaw (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'Jigsaw',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Pehchano',
#   'Name on gamerepo (before lang underscore)': 'MujhePehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': '(double check name)',
#   'Name': 'Nadiya Ke Paar',
#   'Name on gamerepo (before lang underscore)': 'Nadiya Ke Paar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Rhythm',
#   'Name on gamerepo (before lang underscore)': 'Rhythm',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Sangeet',
#   'Name on gamerepo (before lang underscore)': 'Sangeet',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ab Kahan Hai',
#   'Name on gamerepo (before lang underscore)': 'AbKahanHai',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Age Piche',
#   'Name on gamerepo (before lang underscore)': 'AgePiche',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Akshar Khadi',
#   'Name on gamerepo (before lang underscore)': 'Aksharkhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Akshar Matra Shabd Yatra',
#   'Name on gamerepo (before lang underscore)': 'AksharMatra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Balloon Game',
#   'Name on gamerepo (before lang underscore)': 'BalloonGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barahghar',
#   'Name on gamerepo (before lang underscore)': 'Barahghar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi Banao',
#   'Name on gamerepo (before lang underscore)': 'BarakhadiBanao',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Barakhadi Seekho',
#   'Name on gamerepo (before lang underscore)': 'BarakhadiSeekho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Bhaloo ki Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'Bhaloo_ki_Barakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Bhaloo ki Barakhadi',
#   'Name on gamerepo (before lang underscore)': 'BhalooKiBarakhadi',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ek se Anek',
#   'Name on gamerepo (before lang underscore)': 'EkSeAnek',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'GaltiMaaf Sudharo',
#   'Name on gamerepo (before lang underscore)': 'GaltiMaafSudharo',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Gubbare',
#   'Name on gamerepo (before lang underscore)': 'Gubbare',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Hello Hello',
#   'Name on gamerepo (before lang underscore)': 'HelloHello',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Judwa',
#   'Name on gamerepo (before lang underscore)': 'Judwa',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Kahaniya',
#   'Name on gamerepo (before lang underscore)': 'Kahaniyaan',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mind Map Wheel',
#   'Name on gamerepo (before lang underscore)': 'MindMapWheel',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Mujhe Dhundho',
#   'Name on gamerepo (before lang underscore)': 'MujheDhundho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Patta Palat',
#   'Name on gamerepo (before lang underscore)': 'PattaPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Shabda Chitra',
#   'Name on gamerepo (before lang underscore)': 'ShabdhChitra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Suno Pehchano',
#   'Name on gamerepo (before lang underscore)': 'Suno_Pehchano',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Thik Thak',
#   'Name on gamerepo (before lang underscore)': 'ThikThak',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'TracingGame',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Ulat palat',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Dhoom 1',
#   'Name on gamerepo (before lang underscore)': 'Dhoom_1',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Jano Number',
#   'Name on gamerepo (before lang underscore)': 'JaanoNumber',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'LineLagao',
#   'Name on gamerepo (before lang underscore)': 'LineLagao',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number 123',
#   'Name on gamerepo (before lang underscore)': 'Number123',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number kas',
#   'Name on gamerepo (before lang underscore)': 'NumberKas',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number Recognition',
#   'Name on gamerepo (before lang underscore)': 'NumberRecognition',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '6-10 years',
#   'LE Comments': None,
#   'Name': 'Number Recognition',
#   'Name on gamerepo (before lang underscore)': 'NumberRecognition2',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'For Marathi take version from the English repo',
#   'Name': 'Jumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'JumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'English'},
#  {'Age Group': '8-14 years',
#   'LE Comments': '(double check name)',
#   'Name': 'Atulya Bharat',
#   'Name on gamerepo (before lang underscore)': 'Atulya Bharat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jigsaw (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'Jigsaw',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Palat',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Fun'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Aakar',
#   'Name on gamerepo (before lang underscore)': 'Aakar',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Akshar Matra Shabd Yatra',
#   'Name on gamerepo (before lang underscore)': 'AksharMatra',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Correct Pair',
#   'Name on gamerepo (before lang underscore)': 'CorrectPair',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jano Number',
#   'Name on gamerepo (before lang underscore)': 'JaanoNumber',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Jumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'JumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Point me out',
#   'Name on gamerepo (before lang underscore)': 'PointMeOut',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Language'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Count & know',
#   'Name on gamerepo (before lang underscore)': 'CountAndKnow',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Count it',
#   'Name on gamerepo (before lang underscore)': 'CountIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'De Dana Dan',
#   'Name on gamerepo (before lang underscore)': 'Cricket',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': 'No game with similar name found in gamesrepo',
#   'Name': 'De dana dan',
#   'Name on gamerepo (before lang underscore)': 'De dana dan',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Dhoom 2',
#   'Name on gamerepo (before lang underscore)': 'Dhoom_2',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Math'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Ulat Palat (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'UlatPalat2Science',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Science'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': 'Ulat Palat (Marathi)',
#   'Name on gamerepo (before lang underscore)': 'UlatPalatScience',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'Science'},
#  {'Age Group': '8-14 years',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Science'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Automotive'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Beauty'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Construction'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Electrical'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'ABCD',
#   'Name on gamerepo (before lang underscore)': 'ABCD',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Crumble Tumble',
#   'Name on gamerepo (before lang underscore)': 'CrumbleTumble',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Fix-up Mix-up',
#   'Name on gamerepo (before lang underscore)': 'fixUpMixUp',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Flip It',
#   'Name on gamerepo (before lang underscore)': 'FlipIt',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Guess who',
#   'Name on gamerepo (before lang underscore)': 'GuessWho',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': 'Letterbox',
#   'Name on gamerepo (before lang underscore)': 'LetterBox',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': 'This game should be taken from the English gamelist (not in Hindi list)',
#   'Name': 'You said',
#   'Name on gamerepo (before lang underscore)': 'YouSaid',
#   'Pratham': None,
#   'Resource Type': 'Game',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'English- Hindi',
#   'Subject': 'English'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Healthcare'},
#  {'Age Group': '14 and above',
#   'LE Comments': None,
#   'Name': None,
#   'Name on gamerepo (before lang underscore)': None,
#   'Pratham': None,
#   'Resource Type': 'Video Resources',
#   'Subject': 'Hospitality'}]

# %%
game_names = get_all_game_names()

# %%
game_names
# Out:
# ['ABCD',
#  'fixUpMixUp',
#  'Aakar',
#  'Color',
#  'Coloring',
#  'Golmaal',
#  'Rhythm',
#  'Sangeet',
#  'TracingGame',
#  'Aksharkhadi',
#  'AwazChitra',
#  'AwazPehchano',
#  'Barakhadi',
#  'BolBacchaBol',
#  'GuessMe',
#  'MujhePehchano',
#  'ChitraVichitra',
#  'CuriousCases?',
#  'DingDangDing',
#  'NumberKas',
#  'RailGadi',
#  'CrumbleTumble',
#  'FlipIt',
#  'GuessWho',
#  'LetterBox',
#  'PointMeOut',
#  'YouSaid',
#  'Jigsaw',
#  'Nadiya Ke Paar',
#  'GuessMe?',
#  'AbKahanHai',
#  'AgePiche',
#  'AksharMatra',
#  'BalloonGame',
#  'Barahghar',
#  'BarakhadiBanao',
#  'BarakhadiSeekho',
#  'Bhaloo_ki_Barakhadi',
#  'BhalooKiBarakhadi',
#  'EkSeAnek',
#  'GaltiMaafSudharo',
#  'Gubbare',
#  'HelloHello',
#  'Judwa',
#  'Kahaniyaan',
#  'MindMapWheel',
#  'MujheDhundho',
#  'PattaPalat',
#  'ShabdhChitra',
#  'Suno_Pehchano',
#  'ThikThak',
#  'UlatPalat',
#  'Dhoom_1',
#  'JaanoNumber',
#  'LineLagao',
#  'Number123',
#  'NumberRecognition',
#  'NumberRecognition2',
#  'JumbleTumble',
#  'Atulya Bharat',
#  'CorrectPair',
#  'CountAndKnow',
#  'CountIt',
#  'Cricket',
#  'De dana dan',
#  'Dhoom_2',
#  'UlatPalat2Science',
#  'UlatPalatScience']

# %%
from chef import find_undocumented_games

# %%
find_undocumented_games()
# Out:
# fonts_Assamese	Assamese	http://www.gamerepo.prathamcms.org/Zip/Assamese/fonts_Assamese.zip
# fonts_Odiya	Odiya	http://www.gamerepo.prathamcms.org/Zip/Odiya/fonts_Odiya.zip
# fonts_Punjabi	Punjabi	http://www.gamerepo.prathamcms.org/Zip/Punjabi/fonts_Punjabi.zip
# js_Marathi	Marathi	http://www.gamerepo.prathamcms.org/Zip/Marathi/js_Marathi.zip
# fonts
# js

# %%
filter_fn = lambda node: True

# %%
filter_fn('33')
# Out:
# True

# %%
from chef import TEMPLATE_FOR_LANG

# %%
tree_template = TEMPLATE_FOR_LANG.copy()

# %%
tree_template
# Out:
# {'children': [{'children': [{'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Story'},
#     {'children': [], 'title': 'Games'}],
#    'title': '3-6 years'},
#   {'children': [{'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Story'},
#     {'children': [], 'title': 'Games'}],
#    'title': '6-10 years'},
#   {'children': [{'children': [], 'title': 'Mathematics'},
#     {'children': [], 'title': 'Language'},
#     {'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Health'},
#     {'children': [], 'title': 'Science'},
#     {'children': [], 'title': 'Std8'},
#     {'children': [], 'title': 'Fun'},
#     {'children': [], 'title': 'Games'}],
#    'title': '8-14 years'},
#   {'children': [{'children': [], 'title': 'English'},
#     {'children': [], 'title': 'Beauty'},
#     {'children': [], 'title': 'Automotive'},
#     {'children': [], 'title': 'Healthcare'},
#     {'children': [], 'title': 'Construction'},
#     {'children': [], 'title': 'Hospitality'},
#     {'children': [], 'title': 'Electrical'},
#     {'children': [], 'title': 'Games'}],
#    'title': '14 and above'}],
#  'kind': 'lang_template'}

# %%
from chef import find_games_for_lang
games = find_games_for_lang('Aakar', 'hi')

# %%
games
# Out:
# [{'children': [],
#   'kind': 'PradigiGameZipResource',
#   'language_en': 'Hindi',
#   'last_modified': '2/8/18 12:30 PM',
#   'main_file': 'http://www.gamerepo.prathamcms.org/Game/Hindi/Aakar_KKS/index.html',
#   'title': 'Aakar_KKS',
#   'url': 'http://www.gamerepo.prathamcms.org/Zip/Hindi/Aakar_KKS_Hindi.zip'}]

# %%
import requests
resp = requests.get('https://learningequality.org')
print(type(resp.text))         # <class 'str'> (decoded based on resp headers)
print(type(resp.content))      # <class 'bytes'>
json_resp = requests.get('https://api.github.com/orgs/learningequality/repos')
print(type(json_resp.json()))  # <class 'list'>
# Out:
# <class 'str'>
# <class 'bytes'>
# <class 'list'>

# %%
from chef import get_subtree_by_subject_en

subtree= get_subtree_by_subject_en('hi', 'Mathematics')
subtree
# Out:
# {'children': [{'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '106',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES106.png',
#        'title': 'त्रिभुजों के प्रकार ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangle_types.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '107',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES107.png',
#        'title': 'त्रिभुज के मज़ेदार खेल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangle_fun.mp4'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '808',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES808.png',
#        'title': 'त्रिभुज और उसके प्रकार ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 7 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '807',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES807.png',
#        'title': 'त्रिभुज 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 6 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '809',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES809.png',
#        'title': 'त्रिभुज 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 8 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_triangle.html',
#        'source_id': '111',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES111.png',
#        'title': 'त्रिभुज बनायें ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_triangle_est_home.html',
#        'source_id': '828',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES828.png',
#        'title': 'तुक्काबाजी क्षेत्रफल - त्रिभुज ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#      'description': 'त्रिभुज के प्रयोग, मजे और बहुत कुछ\n\n\nत्रिभुज',
#      'kind': 'lesson_page',
#      'source_id': 'LES55',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES55.png',
#      'title': 'त्रिभुज',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES55'},
#     {'children': [{'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '806',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES806.png',
#        'title': 'कोण और उनके प्रकार ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 5 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '103',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES103.png',
#        'title': 'कोण ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_angle.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_angle_est_home.html',
#        'source_id': '184',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES184.png',
#        'title': 'तुक्काबाजी कोण ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '104',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES104.png',
#        'title': 'कोण और उनके प्रकार ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_angle_types.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_angle.html',
#        'source_id': '105',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES105.png',
#        'title': 'कोण बनायें ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#      'description': 'कोण क्या होता है और उसे कैसे नापे?\n\n\nकोण',
#      'kind': 'lesson_page',
#      'source_id': 'LES56',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES56.png',
#      'title': 'कोण',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES56'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '109',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES109.png',
#        'title': 'वृत्त ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_circle.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_circle.html',
#        'source_id': '110',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES110.png',
#        'title': 'वृत्त का खेल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '810',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES810.png',
#        'title': 'वृत्त 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 9 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '811',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES811.png',
#        'title': 'वृत्त 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 10 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_circle_est.html',
#        'source_id': '826',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES826.png',
#        'title': 'तुक्काबाजी क्षेत्रफल - वृत्त ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#      'description': 'दुनिया गोल है- वृत्त को समझें\n\n\nवृत्त',
#      'kind': 'lesson_page',
#      'source_id': 'LES57',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES57.png',
#      'title': 'वृत्त',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES57'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '112',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES112.png',
#        'title': 'परिमाप ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_perimeter.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_perimeter.html',
#        'source_id': '117',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES117.png',
#        'title': 'परिमाप देखें ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_rectangle_est_home.html',
#        'source_id': '840',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES840.png',
#        'title': 'तुक्काबाजी परिमाप - आयत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_square_est_home.html',
#        'source_id': '841',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES841.png',
#        'title': 'तुक्काबाजी परिमाप - वर्ग ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_triangle_est_home.html',
#        'source_id': '842',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES842.png',
#        'title': 'तुक्काबाजी परिमाप - त्रिभुज ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#      'description': 'किनारे को देखकर परिमाप\n\n\nपरिमाप',
#      'kind': 'lesson_page',
#      'source_id': 'LES58',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES58.png',
#      'title': 'परिमाप',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES58'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '108',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES108.png',
#        'title': 'आकृतियाँ और बहुभुज ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/geometry/hn/video/6_2.mp4'}],
#      'description': 'अलग-अलग आकार \n\n\nआकृतियाँ और बहुभुज',
#      'kind': 'lesson_page',
#      'source_id': 'LES74',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES74.png',
#      'title': 'आकृतियाँ और बहुभुज',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES74'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '113',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES113.png',
#        'title': 'क्षेत्रफल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_area.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_area_est_home.html',
#        'source_id': '181',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES181.png',
#        'title': 'तुक्काबाजी क्षेत्रफल - आयत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_rect_est_home.html',
#        'source_id': '827',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES827.png',
#        'title': 'तुक्काबाजी क्षेत्रफल - वर्ग ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#      'description': 'बडा या छोटा?\n\n\nक्षेत्रफल',
#      'kind': 'lesson_page',
#      'source_id': 'LES76',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES76.png',
#      'title': 'क्षेत्रफल',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES76'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS17',
#    'title': 'ज्यामिती से परिचय',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS17'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1539',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1539.png',
#        'title': 'ब्याज की भूमिका ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_interest_intro.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1540',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1540.png',
#        'title': 'साधारण ब्याज की भूमिका ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_simple_interest.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1541',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1541.png',
#        'title': 'साधारण ब्याज उदाहरण ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_simple_int_prob1.mp4'}],
#      'description': 'ब्याज',
#      'kind': 'lesson_page',
#      'source_id': 'LES603',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES603.png',
#      'title': 'ब्याज',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES603'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS98',
#    'title': 'ब्याज',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS98'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1542',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1542.png',
#        'title': 'वर्ग संख्याएँ ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_squares_intro.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1543',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1543.png',
#        'title': 'वर्गमूल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_square_root.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1544',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1544.png',
#        'title': 'खेल खेल में वर्गमूल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_square_fun.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1545',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1545.png',
#        'title': 'त्रिकोणीय संख्याएँ और वर्ग ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangular_square.mp4'}],
#      'description': 'वर्ग संख्याएँ',
#      'kind': 'lesson_page',
#      'source_id': 'LES604',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES604.png',
#      'title': 'वर्ग संख्याएँ',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES604'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS99',
#    'title': 'वर्ग संख्याएँ',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS99'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '165',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES165.png',
#        'title': 'गुणज 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_multiple1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '166',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES166.png',
#        'title': 'गुणज 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_multiple2.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Gunaj_Apvartya(Hindi)/www/MainScreen.html',
#        'source_id': '127',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES127.png',
#        'title': 'बूझो तो सही - गुणज ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Gunaj_Apvartya(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/CricketGameVersionOne_H/CricketGameCoverPage.html',
#        'source_id': '1409',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1409.png',
#        'title': 'दे दनादन!!! ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/CricketGameVersionOne_H.zip'}],
#      'description': 'जिसका भाग जाता है उसे गुणज कहते है\n\n\nगुणज',
#      'kind': 'lesson_page',
#      'source_id': 'LES86',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES86.png',
#      'title': 'गुणज',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES86'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '167',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES167.png',
#        'title': 'गुणनखंड 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_factor1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '168',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES168.png',
#        'title': 'गुणनखंड 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_factor2.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Gunankhand_Apvartak(Hindi)/www/MainScreen.html',
#        'source_id': '128',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES128.png',
#        'title': 'बूझो तो सही - गुणनखंड ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Gunankhand_Apvartak(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/FactorsGameNew_H/gamePage.html',
#        'source_id': '890',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES890.png',
#        'title': 'विभाजक फोडे ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/FactorsGameNew_H.zip'}],
#      'description': 'जो भाग करता है ..वह गुणखंड कहलाता है\n\n\nगुणनखंड',
#      'kind': 'lesson_page',
#      'source_id': 'LES87',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES87.png',
#      'title': 'गुणनखंड',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES87'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '171',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES171.png',
#        'title': 'महत्तम समापवर्तक ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_hcf.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '172',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES172.png',
#        'title': 'अभाज्य गुणनखंडों द्वारा महत्तम समापवर्तक ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_hcf_pf.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi)/www/MainScreen.html',
#        'source_id': '126',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES126.png',
#        'title': 'बूझो तो सही - म.स ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi/primeFactors.html',
#        'source_id': '857',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES857.png\r\n',
#        'title': 'बूझो मेरी संख्या ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi.zip'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '858',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES169.png',
#        'title': 'अभाज्य गुणनखंडन ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_prime_factor.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#        'source_id': '1412',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#        'title': 'कौनसी बाल्टी? ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#      'description': 'महत्तम समापवर्तक का सिद्धांत और उसको मापना\n\n\nमहत्तम समापवर्तक',
#      'kind': 'lesson_page',
#      'source_id': 'LES88',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES88.png',
#      'title': 'महत्तम समापवर्तक',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES88'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '173',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES173.png',
#        'title': 'लघुतम समापवर्त्य ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '174',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES174.png',
#        'title': 'अभाज्य गुणनखंडो द्वारा लघुतम समापवर्त्य ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm_pf.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi)/www/MainScreen.html',
#        'source_id': '125',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES125.png',
#        'title': 'बूझो तो सही - ल.स ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi/primeFactors.html',
#        'source_id': '857',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES857.png\r\n',
#        'title': 'बूझो मेरी संख्या ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi.zip'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '858',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES169.png',
#        'title': 'अभाज्य गुणनखंडन ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_prime_factor.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '456',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES456.png',
#        'title': 'दोस्ती की ट्रेन ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_lcm_train.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#        'source_id': '1412',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#        'title': 'कौनसी बाल्टी? ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#      'description': 'लघुत्तम समापवर्त्य\xa0का सिद्धांत और उसको मापना\n\n\nलघुत्तम समापवर्त्य',
#      'kind': 'lesson_page',
#      'source_id': 'LES89',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES89.png',
#      'title': 'लघुत्तम समापवर्त्य',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES89'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '175',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES175.png',
#        'title': 'म.स. और ल.स. के मजेदार खेल ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm_hcf_fun.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi)/www/MainScreen.html',
#        'source_id': '125',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES125.png',
#        'title': 'बूझो तो सही - ल.स ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi)/www/MainScreen.html',
#        'source_id': '126',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES126.png',
#        'title': 'बूझो तो सही - म.स ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi).zip'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#        'source_id': '1412',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#        'title': 'कौनसी बाल्टी? ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#      'description': 'महत्तम समापवर्तक और लघुत्तम समापवर्त्य\xa0के मजेदार खेल देखें\n\n\nमहत्तम समापवर्तक, लघुत्तम समापवर्त्य',
#      'kind': 'lesson_page',
#      'source_id': 'LES90',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES90.png',
#      'title': 'महत्तम समापवर्तक, लघुत्तम समापवर्त्य',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES90'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '457',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES457.png',
#        'title': 'रिश्ते परिवार में और गणित में 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_math_relations1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '458',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES458.png',
#        'title': 'रिश्ते परिवार में और गणित में 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_math_relations2.mp4'}],
#      'description': 'गणित दैनिक जीवन से प्रेरित\n\n\nरिश्ते गणित में',
#      'kind': 'lesson_page',
#      'source_id': 'LES537',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES537.png',
#      'title': 'रिश्ते गणित में',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES537'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS27',
#    'title': 'गुणज और गुणनखंड',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS27'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1343',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1343.png',
#        'title': 'भिन्नों को जोड़ ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_addition.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1344',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1344.png',
#        'title': 'भिन्नों को घटाव ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_subtraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1345',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1345.png',
#        'title': 'भिन्नों का गुणा ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_multiplication1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1346',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1346.png',
#        'title': 'गुणात्मक प्रतिलोम ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_multiplication2.mp4'}],
#      'description': 'भिन्न\xa0के मित्र\n\n\nभिन्न में और क्या!',
#      'kind': 'lesson_page',
#      'source_id': 'LES509',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES509.png',
#      'title': 'भिन्न में और क्या!',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES509'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1362',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1362.png',
#        'title': 'दशमलव संख्याओ को जोड़ना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_addition.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1363',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1363.png',
#        'title': 'दशमलव संख्यओं को घटाना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_subtraction.mp4'}],
#      'description': 'दशमलव में और क्या!',
#      'kind': 'lesson_page',
#      'source_id': 'LES513',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES513.png',
#      'title': 'दशमलव में और क्या!',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES513'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '891',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES891.png',
#        'title': 'दशमलव  ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_decimal.html',
#        'source_id': '886',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES886.png',
#        'title': 'दशांश अपूर्णांक ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '805',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES805.png',
#        'title': 'दशमलव भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 4 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1364',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1364.png',
#        'title': 'दशमलव संख्या से भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_fraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1365',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1365.png',
#        'title': 'भिन्न से दशमलव ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_decimal.mp4'}],
#      'description': 'दो अंकों के बीच',
#      'kind': 'lesson_page',
#      'source_id': 'LES514',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES514.png',
#      'title': 'दो अंकों के बीच',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES514'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1366',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1366.png',
#        'title': 'प्रतिशत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_percent.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1367',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1367.png',
#        'title': 'प्रतिशत भिन्नों के रूप में ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_percent_fraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1368',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1368.png',
#        'title': 'भिन्न प्रतिशत के रूप में ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_percent.mp4'}],
#      'description': 'सौ में से कितने?',
#      'kind': 'lesson_page',
#      'source_id': 'LES515',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES515.png',
#      'title': 'सौ में से कितने?',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES515'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '114',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES114.png',
#        'title': 'भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '115',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES115.png',
#        'title': 'भिन्नों की तुलना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_compare.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '851',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES851.png',
#        'title': 'समतुल्य भिन्नें  ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_equivalent_fraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/newFractionGame_H/MainPage.html',
#        'source_id': '889',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES889.png',
#        'title': 'रंगीन भिन्ने ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/newFractionGame_H.zip'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1121',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1121.png',
#        'title': 'भिन्नों के प्रकार ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_types.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1122',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1122.png',
#        'title': 'भिन्न का सरलतम रूप ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_lowest.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '1123',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1123.png',
#        'title': 'अनुचित भिन्न औरमिश्रित भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_improper_mixed.mp4'}],
#      'description': 'अंक के भाग',
#      'kind': 'lesson_page',
#      'source_id': 'LES112',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES112.png',
#      'title': 'अंक के भाग',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES112'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS82',
#    'title': 'अलग संख्याएँ',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS82'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '860',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES860.png',
#        'title': 'मात्राएँ और संख्याएँ भाग 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '861',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES861.png',
#        'title': 'मात्राएँ और संख्याएँ भाग 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure2.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '862',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES862.png',
#        'title': 'मात्राएँ और संख्याएँ भाग 3 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure3.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '863',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES863.png',
#        'title': 'मात्राएँ और संख्याएँ भाग 4 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure4.mp4'}],
#      'description': 'परिमाण क्या  परिणाम करता है?\n\n\nमात्राएँ और संख्याएँ',
#      'kind': 'lesson_page',
#      'source_id': 'LES107',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES107.png',
#      'title': 'मात्राएँ और संख्याएँ',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES107'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS41',
#    'title': 'मात्राएँ और संख्याएँ',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS41'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '116',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES116.png',
#        'title': 'प्रतिशत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/3.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_percentage.html',
#        'source_id': '118',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES118.png',
#        'title': 'प्रतिशत देखें ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '803',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES803.png',
#        'title': 'प्रतिशतता ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 2 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '859',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES859.png',
#        'title': 'मौखिक प्रतिशत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_percent_mental.mp4'}],
#      'description': 'सौ में कितने\n\n\nप्रतिशत',
#      'kind': 'lesson_page',
#      'source_id': 'LES75',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES75.png',
#      'title': 'प्रतिशत',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES75'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS24',
#    'title': 'प्रतिशत',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS24'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '163',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES163.png',
#        'title': 'बीजगणित की भूमिका 1 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_algebra_intro1.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '164',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES164.png',
#        'title': 'बीजगणित की भूमिका 2 ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_algebra_intro2.mp4'}],
#      'description': 'बीजगणित की पहेली!\n\n\nबीजगणित की भूमिका',
#      'kind': 'lesson_page',
#      'source_id': 'LES85',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES85.png',
#      'title': 'बीजगणित की भूमिका',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES85'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS21',
#    'title': 'बीजगणित से परिचय',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS21'},
#   {'children': [{'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '849',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES849.png',
#        'title': 'दशमलव संख्या से भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_to_fraction.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '850',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES850.png',
#        'title': 'दशमलव संख्याओं को विभाजित करना (भाग २) ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_dividing_decimal2.mp4'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/PlaceValueHindi/main.html',
#        'source_id': '864',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES864.png',
#        'title': 'बूझो मेरी कीमत ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/PlaceValueHindi.zip'},
#       {'children': [],
#        'kind': 'PrathamPdfResource',
#        'source_id': '805',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES805.png',
#        'title': 'दशमलव भिन्न ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 4 - H.pdf'},
#       {'children': [],
#        'kind': 'PrathamZipResource',
#        'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_decimal.html',
#        'source_id': '886',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES886.png',
#        'title': 'दशांश अपूर्णांक ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '891',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES891.png',
#        'title': 'दशमलव  ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '892',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES892.png',
#        'title': 'दशांश अपूर्णांक तुलना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_compare.mp4'}],
#      'description': 'दो अंको के बीच आनेवाली संख्या\n\n\nदशमलव',
#      'kind': 'lesson_page',
#      'source_id': 'LES100',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES100.png',
#      'title': 'दशमलव',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES100'},
#     {'children': [{'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '847',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES847.png',
#        'title': 'दशमलव संख्याओं को जोड़ना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_addition.mp4'},
#       {'children': [],
#        'kind': 'PrathamVideoResource',
#        'source_id': '848',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES848.png',
#        'title': 'दशमलव संख्याओं को घटाना ',
#        'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_subtraction.mp4'}],
#      'description': 'दशमलव संख्याओ के साथ क्या क्या कर सकते हो?\n\n\nदशमलव जोडना,घटाना',
#      'kind': 'lesson_page',
#      'source_id': 'LES101',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES101.png',
#      'title': 'दशमलव जोडना,घटाना',
#      'url': 'http://www.prathamopenschool.org/hn/Lesson/LES101'}],
#    'kind': 'subtopic_page',
#    'source_id': 'CRS40',
#    'title': 'दशमलव',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS40'}],
#  'kind': 'topic_page',
#  'source_id': 'Mathematics',
#  'subject_en': 'Mathematics',
#  'title': 'गणित',
#  'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics'}

# %%
import json
lang = 'hi'
wrt_filename = 'chefdata/trees/pradigi_{}_web_resource_tree.json'.format(lang)
with open(wrt_filename) as jsonfile:
    web_resource_tree = json.load(jsonfile)
# Out:
# {'children': [{'children': [{'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '106',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES106.png',
#          'title': 'त्रिभुजों के प्रकार ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangle_types.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '107',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES107.png',
#          'title': 'त्रिभुज के मज़ेदार खेल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangle_fun.mp4'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '808',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES808.png',
#          'title': 'त्रिभुज और उसके प्रकार ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 7 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '807',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES807.png',
#          'title': 'त्रिभुज 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 6 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '809',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES809.png',
#          'title': 'त्रिभुज 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 8 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_triangle.html',
#          'source_id': '111',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES111.png',
#          'title': 'त्रिभुज बनायें ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_triangle_est_home.html',
#          'source_id': '828',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES828.png',
#          'title': 'तुक्काबाजी क्षेत्रफल - त्रिभुज ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#        'description': 'त्रिभुज के प्रयोग, मजे और बहुत कुछ\n\n\nत्रिभुज',
#        'kind': 'lesson_page',
#        'source_id': 'LES55',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES55.png',
#        'title': 'त्रिभुज',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES55'},
#       {'children': [{'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '806',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES806.png',
#          'title': 'कोण और उनके प्रकार ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 5 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '103',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES103.png',
#          'title': 'कोण ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_angle.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_angle_est_home.html',
#          'source_id': '184',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES184.png',
#          'title': 'तुक्काबाजी कोण ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '104',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES104.png',
#          'title': 'कोण और उनके प्रकार ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_angle_types.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_angle.html',
#          'source_id': '105',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES105.png',
#          'title': 'कोण बनायें ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#        'description': 'कोण क्या होता है और उसे कैसे नापे?\n\n\nकोण',
#        'kind': 'lesson_page',
#        'source_id': 'LES56',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES56.png',
#        'title': 'कोण',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES56'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '109',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES109.png',
#          'title': 'वृत्त ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_circle.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_circle.html',
#          'source_id': '110',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES110.png',
#          'title': 'वृत्त का खेल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '810',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES810.png',
#          'title': 'वृत्त 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 9 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '811',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES811.png',
#          'title': 'वृत्त 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 10 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_circle_est.html',
#          'source_id': '826',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES826.png',
#          'title': 'तुक्काबाजी क्षेत्रफल - वृत्त ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#        'description': 'दुनिया गोल है- वृत्त को समझें\n\n\nवृत्त',
#        'kind': 'lesson_page',
#        'source_id': 'LES57',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES57.png',
#        'title': 'वृत्त',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES57'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '112',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES112.png',
#          'title': 'परिमाप ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_perimeter.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_perimeter.html',
#          'source_id': '117',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES117.png',
#          'title': 'परिमाप देखें ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_rectangle_est_home.html',
#          'source_id': '840',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES840.png',
#          'title': 'तुक्काबाजी परिमाप - आयत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_square_est_home.html',
#          'source_id': '841',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES841.png',
#          'title': 'तुक्काबाजी परिमाप - वर्ग ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_peri_triangle_est_home.html',
#          'source_id': '842',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES842.png',
#          'title': 'तुक्काबाजी परिमाप - त्रिभुज ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#        'description': 'किनारे को देखकर परिमाप\n\n\nपरिमाप',
#        'kind': 'lesson_page',
#        'source_id': 'LES58',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES58.png',
#        'title': 'परिमाप',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES58'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '108',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES108.png',
#          'title': 'आकृतियाँ और बहुभुज ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/geometry/hn/video/6_2.mp4'}],
#        'description': 'अलग-अलग आकार \n\n\nआकृतियाँ और बहुभुज',
#        'kind': 'lesson_page',
#        'source_id': 'LES74',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES74.png',
#        'title': 'आकृतियाँ और बहुभुज',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES74'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '113',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES113.png',
#          'title': 'क्षेत्रफल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_area.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_area_est_home.html',
#          'source_id': '181',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES181.png',
#          'title': 'तुक्काबाजी क्षेत्रफल - आयत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_rect_est_home.html',
#          'source_id': '827',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES827.png',
#          'title': 'तुक्काबाजी क्षेत्रफल - वर्ग ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'}],
#        'description': 'बडा या छोटा?\n\n\nक्षेत्रफल',
#        'kind': 'lesson_page',
#        'source_id': 'LES76',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES76.png',
#        'title': 'क्षेत्रफल',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES76'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS17',
#      'title': 'ज्यामिती से परिचय',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS17'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1539',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1539.png',
#          'title': 'ब्याज की भूमिका ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_interest_intro.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1540',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1540.png',
#          'title': 'साधारण ब्याज की भूमिका ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_simple_interest.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1541',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1541.png',
#          'title': 'साधारण ब्याज उदाहरण ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_simple_int_prob1.mp4'}],
#        'description': 'ब्याज',
#        'kind': 'lesson_page',
#        'source_id': 'LES603',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES603.png',
#        'title': 'ब्याज',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES603'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS98',
#      'title': 'ब्याज',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS98'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1542',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1542.png',
#          'title': 'वर्ग संख्याएँ ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_squares_intro.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1543',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1543.png',
#          'title': 'वर्गमूल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_square_root.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1544',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1544.png',
#          'title': 'खेल खेल में वर्गमूल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_square_fun.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1545',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Images/RES1545.png',
#          'title': 'त्रिकोणीय संख्याएँ और वर्ग ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_triangular_square.mp4'}],
#        'description': 'वर्ग संख्याएँ',
#        'kind': 'lesson_page',
#        'source_id': 'LES604',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES604.png',
#        'title': 'वर्ग संख्याएँ',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES604'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS99',
#      'title': 'वर्ग संख्याएँ',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS99'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '165',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES165.png',
#          'title': 'गुणज 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_multiple1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '166',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES166.png',
#          'title': 'गुणज 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_multiple2.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Gunaj_Apvartya(Hindi)/www/MainScreen.html',
#          'source_id': '127',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES127.png',
#          'title': 'बूझो तो सही - गुणज ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Gunaj_Apvartya(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/CricketGameVersionOne_H/CricketGameCoverPage.html',
#          'source_id': '1409',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1409.png',
#          'title': 'दे दनादन!!! ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/CricketGameVersionOne_H.zip'}],
#        'description': 'जिसका भाग जाता है उसे गुणज कहते है\n\n\nगुणज',
#        'kind': 'lesson_page',
#        'source_id': 'LES86',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES86.png',
#        'title': 'गुणज',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES86'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '167',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES167.png',
#          'title': 'गुणनखंड 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_factor1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '168',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES168.png',
#          'title': 'गुणनखंड 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_factor2.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Gunankhand_Apvartak(Hindi)/www/MainScreen.html',
#          'source_id': '128',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES128.png',
#          'title': 'बूझो तो सही - गुणनखंड ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Gunankhand_Apvartak(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/FactorsGameNew_H/gamePage.html',
#          'source_id': '890',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES890.png',
#          'title': 'विभाजक फोडे ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/FactorsGameNew_H.zip'}],
#        'description': 'जो भाग करता है ..वह गुणखंड कहलाता है\n\n\nगुणनखंड',
#        'kind': 'lesson_page',
#        'source_id': 'LES87',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES87.png',
#        'title': 'गुणनखंड',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES87'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '171',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES171.png',
#          'title': 'महत्तम समापवर्तक ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_hcf.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '172',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES172.png',
#          'title': 'अभाज्य गुणनखंडों द्वारा महत्तम समापवर्तक ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_hcf_pf.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi)/www/MainScreen.html',
#          'source_id': '126',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES126.png',
#          'title': 'बूझो तो सही - म.स ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi/primeFactors.html',
#          'source_id': '857',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES857.png\r\n',
#          'title': 'बूझो मेरी संख्या ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi.zip'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '858',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES169.png',
#          'title': 'अभाज्य गुणनखंडन ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_prime_factor.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#          'source_id': '1412',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#          'title': 'कौनसी बाल्टी? ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#        'description': 'महत्तम समापवर्तक का सिद्धांत और उसको मापना\n\n\nमहत्तम समापवर्तक',
#        'kind': 'lesson_page',
#        'source_id': 'LES88',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES88.png',
#        'title': 'महत्तम समापवर्तक',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES88'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '173',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES173.png',
#          'title': 'लघुतम समापवर्त्य ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '174',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES174.png',
#          'title': 'अभाज्य गुणनखंडो द्वारा लघुतम समापवर्त्य ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm_pf.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi)/www/MainScreen.html',
#          'source_id': '125',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES125.png',
#          'title': 'बूझो तो सही - ल.स ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi/primeFactors.html',
#          'source_id': '857',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES857.png\r\n',
#          'title': 'बूझो मेरी संख्या ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/primeFactorsHindi.zip'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '858',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES169.png',
#          'title': 'अभाज्य गुणनखंडन ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_prime_factor.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '456',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES456.png',
#          'title': 'दोस्ती की ट्रेन ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_lcm_train.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#          'source_id': '1412',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#          'title': 'कौनसी बाल्टी? ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#        'description': 'लघुत्तम समापवर्त्य\xa0का सिद्धांत और उसको मापना\n\n\nलघुत्तम समापवर्त्य',
#        'kind': 'lesson_page',
#        'source_id': 'LES89',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES89.png',
#        'title': 'लघुत्तम समापवर्त्य',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES89'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '175',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES175.png',
#          'title': 'म.स. और ल.स. के मजेदार खेल ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Multiples-Factors/hn/h_lcm_hcf_fun.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi)/www/MainScreen.html',
#          'source_id': '125',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES125.png',
#          'title': 'बूझो तो सही - ल.स ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/L.S(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi)/www/MainScreen.html',
#          'source_id': '126',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES126.png',
#          'title': 'बूझो तो सही - म.स ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/M.S(Hindi).zip'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H/BucketGame.html',
#          'source_id': '1412',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1412.png',
#          'title': 'कौनसी बाल्टी? ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/MathsBucketGame_H.zip'}],
#        'description': 'महत्तम समापवर्तक और लघुत्तम समापवर्त्य\xa0के मजेदार खेल देखें\n\n\nमहत्तम समापवर्तक, लघुत्तम समापवर्त्य',
#        'kind': 'lesson_page',
#        'source_id': 'LES90',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES90.png',
#        'title': 'महत्तम समापवर्तक, लघुत्तम समापवर्त्य',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES90'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '457',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES457.png',
#          'title': 'रिश्ते परिवार में और गणित में 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_math_relations1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '458',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES458.png',
#          'title': 'रिश्ते परिवार में और गणित में 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_math_relations2.mp4'}],
#        'description': 'गणित दैनिक जीवन से प्रेरित\n\n\nरिश्ते गणित में',
#        'kind': 'lesson_page',
#        'source_id': 'LES537',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES537.png',
#        'title': 'रिश्ते गणित में',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES537'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS27',
#      'title': 'गुणज और गुणनखंड',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS27'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1343',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1343.png',
#          'title': 'भिन्नों को जोड़ ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_addition.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1344',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1344.png',
#          'title': 'भिन्नों को घटाव ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_subtraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1345',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1345.png',
#          'title': 'भिन्नों का गुणा ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_multiplication1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1346',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1346.png',
#          'title': 'गुणात्मक प्रतिलोम ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_multiplication2.mp4'}],
#        'description': 'भिन्न\xa0के मित्र\n\n\nभिन्न में और क्या!',
#        'kind': 'lesson_page',
#        'source_id': 'LES509',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES509.png',
#        'title': 'भिन्न में और क्या!',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES509'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1362',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1362.png',
#          'title': 'दशमलव संख्याओ को जोड़ना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_addition.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1363',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1363.png',
#          'title': 'दशमलव संख्यओं को घटाना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_subtraction.mp4'}],
#        'description': 'दशमलव में और क्या!',
#        'kind': 'lesson_page',
#        'source_id': 'LES513',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES513.png',
#        'title': 'दशमलव में और क्या!',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES513'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '891',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES891.png',
#          'title': 'दशमलव  ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_decimal.html',
#          'source_id': '886',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES886.png',
#          'title': 'दशांश अपूर्णांक ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '805',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES805.png',
#          'title': 'दशमलव भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 4 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1364',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1364.png',
#          'title': 'दशमलव संख्या से भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_fraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1365',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1365.png',
#          'title': 'भिन्न से दशमलव ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_decimal.mp4'}],
#        'description': 'दो अंकों के बीच',
#        'kind': 'lesson_page',
#        'source_id': 'LES514',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES514.png',
#        'title': 'दो अंकों के बीच',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES514'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1366',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1366.png',
#          'title': 'प्रतिशत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_percent.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1367',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1367.png',
#          'title': 'प्रतिशत भिन्नों के रूप में ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_percent_fraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1368',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1368.png',
#          'title': 'भिन्न प्रतिशत के रूप में ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_percent.mp4'}],
#        'description': 'सौ में से कितने?',
#        'kind': 'lesson_page',
#        'source_id': 'LES515',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES515.png',
#        'title': 'सौ में से कितने?',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES515'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '114',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES114.png',
#          'title': 'भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '115',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES115.png',
#          'title': 'भिन्नों की तुलना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_compare.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '851',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES851.png',
#          'title': 'समतुल्य भिन्नें  ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_equivalent_fraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/newFractionGame_H/MainPage.html',
#          'source_id': '889',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES889.png',
#          'title': 'रंगीन भिन्ने ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/newFractionGame_H.zip'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1121',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1121.png',
#          'title': 'भिन्नों के प्रकार ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_types.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1122',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1122.png',
#          'title': 'भिन्न का सरलतम रूप ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_fraction_lowest.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '1123',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES1123.png',
#          'title': 'अनुचित भिन्न औरमिश्रित भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_improper_mixed.mp4'}],
#        'description': 'अंक के भाग',
#        'kind': 'lesson_page',
#        'source_id': 'LES112',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES112.png',
#        'title': 'अंक के भाग',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES112'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS82',
#      'title': 'अलग संख्याएँ',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS82'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '860',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES860.png',
#          'title': 'मात्राएँ और संख्याएँ भाग 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '861',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES861.png',
#          'title': 'मात्राएँ और संख्याएँ भाग 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure2.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '862',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES862.png',
#          'title': 'मात्राएँ और संख्याएँ भाग 3 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure3.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '863',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES863.png',
#          'title': 'मात्राएँ और संख्याएँ भाग 4 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_quantityNmeasure4.mp4'}],
#        'description': 'परिमाण क्या  परिणाम करता है?\n\n\nमात्राएँ और संख्याएँ',
#        'kind': 'lesson_page',
#        'source_id': 'LES107',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES107.png',
#        'title': 'मात्राएँ और संख्याएँ',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES107'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS41',
#      'title': 'मात्राएँ और संख्याएँ',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS41'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '116',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES116.png',
#          'title': 'प्रतिशत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/3.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_percentage.html',
#          'source_id': '118',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES118.png',
#          'title': 'प्रतिशत देखें ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '803',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES803.png',
#          'title': 'प्रतिशतता ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 2 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '859',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES859.png',
#          'title': 'मौखिक प्रतिशत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_percent_mental.mp4'}],
#        'description': 'सौ में कितने\n\n\nप्रतिशत',
#        'kind': 'lesson_page',
#        'source_id': 'LES75',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES75.png',
#        'title': 'प्रतिशत',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES75'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS24',
#      'title': 'प्रतिशत',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS24'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '163',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES163.png',
#          'title': 'बीजगणित की भूमिका 1 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_algebra_intro1.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '164',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES164.png',
#          'title': 'बीजगणित की भूमिका 2 ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Algebra/hn/video/h_algebra_intro2.mp4'}],
#        'description': 'बीजगणित की पहेली!\n\n\nबीजगणित की भूमिका',
#        'kind': 'lesson_page',
#        'source_id': 'LES85',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES85.png',
#        'title': 'बीजगणित की भूमिका',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES85'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS21',
#      'title': 'बीजगणित से परिचय',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS21'},
#     {'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '849',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES849.png',
#          'title': 'दशमलव संख्या से भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_to_fraction.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '850',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES850.png',
#          'title': 'दशमलव संख्याओं को विभाजित करना (भाग २) ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_dividing_decimal2.mp4'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/PlaceValueHindi/main.html',
#          'source_id': '864',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES864.png',
#          'title': 'बूझो मेरी कीमत ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/PlaceValueHindi.zip'},
#         {'children': [],
#          'kind': 'PrathamPdfResource',
#          'source_id': '805',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES805.png',
#          'title': 'दशमलव भिन्न ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Read/Hindi/Reading Cards 4 - H.pdf'},
#         {'children': [],
#          'kind': 'PrathamZipResource',
#          'main_file': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics/hn_decimal.html',
#          'source_id': '886',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES886.png',
#          'title': 'दशांश अपूर्णांक ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Games/Mathematics.zip'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '891',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES891.png',
#          'title': 'दशमलव  ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '892',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES892.png',
#          'title': 'दशांश अपूर्णांक तुलना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_decimal_compare.mp4'}],
#        'description': 'दो अंको के बीच आनेवाली संख्या\n\n\nदशमलव',
#        'kind': 'lesson_page',
#        'source_id': 'LES100',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES100.png',
#        'title': 'दशमलव',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES100'},
#       {'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '847',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES847.png',
#          'title': 'दशमलव संख्याओं को जोड़ना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_addition.mp4'},
#         {'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '848',
#          'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/images/RES848.png',
#          'title': 'दशमलव संख्याओं को घटाना ',
#          'url': 'http://www.prathamopenschool.org/CourseContent/Mathematics/Decimals/hn/video/h_decimal_subtraction.mp4'}],
#        'description': 'दशमलव संख्याओ के साथ क्या क्या कर सकते हो?\n\n\nदशमलव जोडना,घटाना',
#        'kind': 'lesson_page',
#        'source_id': 'LES101',
#        'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/CourseLession/LES101.png',
#        'title': 'दशमलव जोडना,घटाना',
#        'url': 'http://www.prathamopenschool.org/hn/Lesson/LES101'}],
#      'kind': 'subtopic_page',
#      'source_id': 'CRS40',
#      'title': 'दशमलव',
#      'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics/CRS40'}],
#    'kind': 'topic_page',
#    'source_id': 'Mathematics',
#    'subject_en': 'Mathematics',
#    'title': 'गणित',
#    'url': 'http://www.prathamopenschool.org/hn/Course/Mathematics'},
#   {'children': [{'children': [{'children': [{'children': [],
#          'kind': 'PrathamVideoResource',
#          'source_id': '199',
# ...
#      'url': 'http://www.prathamopenschool.org/CourseContent/Games/HistoryOfPlane_H.zip'},
#     {'children': [],
#      'kind': 'PrathamVideoResource',
#      'source_id': 'hn/FunResource/1566',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Science/Images/RES1566.png',
#      'title': 'कैसे दौड़ते हैं ?',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_howToRun.mp4'},
#     {'children': [],
#      'kind': 'PrathamVideoResource',
#      'source_id': 'hn/FunResource/308',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Science/Images/RES301.png',
#      'title': 'अंतरिक्ष में पानी निचोड़ना',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Science/Watch/hn/SCIENCE/h_dry_clothes.mp4'},
#     {'children': [],
#      'kind': 'PrathamVideoResource',
#      'source_id': 'hn/FunResource/1555',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Science/Images/RES1555.png',
#      'title': 'पूलों का रहस्य',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Science/Videos/h_bridge_secret.mp4'},
#     {'children': [],
#      'kind': 'PrathamVideoResource',
#      'source_id': 'hn/FunResource/376',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Science/Images/RES376.png',
#      'title': 'स्ट्रॉ को घुमानेवाला',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Science/Watch/hn/SCIENCE/h_electric_straw1.mp4'}],
#    'kind': 'fun_page',
#    'source_id': 'Fun',
#    'subject_en': 'Fun',
#    'title': 'मौज',
#    'url': 'http://www.prathamopenschool.org/hn/Fun'},
#   {'children': [{'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1044',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1044.png',
#      'title': 'नानी की ऐनक',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Grandmas_Glasses.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1053',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1053.png',
#      'title': 'बुलबुलों वाला फेनीला दूध',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Moo_Moo_Brown_Cow.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1036',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1036.png',
#      'title': 'चुस्कित स्कूल चली',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Chuskit_Goes_to_School.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1062',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1062.png',
#      'title': 'छुटकू मकड़ा',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Spincy_Spider.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1065',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1065.png',
#      'title': 'कुहू कुहू कोयल',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Koels_Song.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1055',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1055.png',
#      'title': 'हमारी खूबसूरत दुनिया',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Our_Wonderful_World.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1035',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1035.png',
#      'title': 'चुलबुल की पूँछ',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Chulbuls_Tail.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1042',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1042.png',
#      'title': 'चाचा की शादी',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Going_to_a_Wedding.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1066',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1066.png',
#      'title': 'लापता बल्ला',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Missing_Bat.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1068',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1068.png',
#      'title': 'रंग बिरंगी सुंदर मछली',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Rainbow_Fish.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1069',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1069.png',
#      'title': 'गौरेया और अमरूद',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Sparrow_and_the_Fruit.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1031',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1031.png',
#      'title': 'सालाना बाल - कटाई दिवस',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Annual_Haircut_Day.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1060',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1060.png',
#      'title': 'शोभिनी और नानी',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Shobhini_and_Nani.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1046',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1046.png',
#      'title': 'एक यादगार मेला',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/History-Series-01.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1058',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1058.png',
#      'title': 'नौका विहार',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Row_Your_Boat.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1047',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1047.png',
#      'title': 'अगस्त का एक दिन',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/History-Series-02.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1067',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1067.png',
#      'title': 'टूटी चोंच वाला तोता',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Parrot_with_a_Broken_Beak.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1050',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1050.png',
#      'title': 'कल्लू के किस्से १',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Kallus-World-01.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1030',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1030.png',
#      'title': 'अनया का अंगूठा',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Anayas_Thumb.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1041',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1041.png',
#      'title': 'पैसे की यात्रा',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Finance-02-Hindi.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1037',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1037.png',
#      'title': 'मोरू एक पहेली',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Counting_on_Moru.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1043',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1043.png',
#      'title': 'सो जाओ टिंकु !',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Goodnight_Tinku.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1059',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1059.png',
#      'title': 'शान्ति का मित्र',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Shantis-Friend-Hindi.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1034',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1034.png',
#      'title': 'कबाड़ी वाला',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Cheenus_Gift.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1040',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1040.png',
#      'title': 'पैसे की दुनिया',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Finance-01.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1052',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1052.png',
#      'title': 'एक बड़ी मुसीबत',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Kato_Clever_and_the_Big_Trouble.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1054',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1054.png',
#      'title': 'हँसना मना है',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/No_smiles_today.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1051',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1051.png',
#      'title': 'कल्लू के किस्से २',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Kallus-World-02.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1033',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1033.png',
#      'title': 'घाट की मायावी बिल्ली',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Cat-in-the-ghat.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1064',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1064.png',
#      'title': 'कछुआ और खरगोश',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Hare_and_the_Tortoise.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1039',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1039.png',
#      'title': 'मनु ने बनाया खुशियों का घड़ा',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Dastkari-Series-03.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1063',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1063.png',
#      'title': 'कौए के रिश्तेदार',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/The_Generous_Crow.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1038',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1038.png',
#      'title': 'पापा की मूँछें',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Daddys_Mo.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1032',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1032.png',
#      'title': 'जुई मौसी की बेटी',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Aunty_Juis_Baby.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1049',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1049.png',
#      'title': 'काका और मुन्नी',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Kaka_and_Munni.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1061',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1061.png',
#      'title': 'रोन्दू और मुक्की',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Sniffles_the_Crocodile_and_Punch.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1045',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1045.png',
#      'title': 'मछली ने समाचार सुने',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Grandpa_Fish_and_Radio.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1057',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1057.png',
#      'title': 'बरसा बादल',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Rain_Rain.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1056',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1056.png',
#      'title': 'पपलू राक्षस',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Paplu_The_Giant.pdf'},
#     {'children': [],
#      'kind': 'story_resource_page',
#      'source_id': 'hn/StoryResource/1048',
#      'thumbnail_url': 'http://www.prathamopenschool.org/CourseContent/Story/Images/RES1048.png',
#      'title': 'मसाला चाय',
#      'url': 'http://www.prathamopenschool.org/CourseContent/Story/PDF/Hindi/Jungle-Brew-Hindi.pdf'}],
#    'kind': 'story_page',
#    'source_id': 'Story',
#    'subject_en': 'Story',
#    'title': 'कहानियाँ',
#    'url': 'http://www.prathamopenschool.org/hn/Story'},
#   {'children': [{'children': [],
#      'kind': 'subtopic_page',
#      'source_id': 'LES620',
#      'title': '3 to 6',
#      'url': 'http://www.prathamopenschool.org/hn/gamelist/CRS104/LES620'},
#     {'children': [],
#      'kind': 'subtopic_page',
#      'source_id': 'LES621',
#      'title': '6 to 10',
#      'url': 'http://www.prathamopenschool.org/hn/gamelist/CRS104/LES621'},
#     {'children': [],
#      'kind': 'subtopic_page',
#      'source_id': 'LES622',
#      'title': '10 to 14',
#      'url': 'http://www.prathamopenschool.org/hn/gamelist/CRS104/LES622'}],
#    'kind': 'topic_page',
#    'source_id': 'CRS104',
#    'subject_en': 'CRS104',
#    'title': 'खेल',
#    'url': 'http://www.prathamopenschool.org/hn/gamelist/CRS104'}],
#  'description': 'PraDigi video lessons and games.',
#  'kind': 'lang_page',
#  'language': 'hi',
#  'source_domain': 'prathamopenschool.org',
#  'source_id': 'pratham-open-school-hi',
#  'thumbnail': None,
#  'title': 'PraDigi (हिन्दी, हिंदी)',
#  'url': 'http://www.prathamopenschool.org/hn/'}

# %%
import requests
resp = requests.head('http://www.prathamopenschool.org/CourseContent/Mathematics/Videos/h_perimeter.mp4')
resp.headers
# Out:
# {'Content-Length': '1245', 'Content-Type': 'text/html', 'Server': 'Microsoft-IIS/8.5', 'X-Powered-By': 'ASP.NET', 'Date': 'Tue, 13 Mar 2018 15:46:58 GMT'}
